# %% [markdown]
# # Plotting Examples

# %%
# imports
import plotly.express as px
import plotly as pt
import pandas as pd
import seaborn as sb
import json
import os

# %%
# load data
data = pd.read_csv('../SpeciesData_Rounded-1.csv')

# %%
data_1.head(5)
# Out:
#    id   lat    lon sensor method                 date  CAWA
# 0   1  54.9 -111.7    ARU   1SPT  2021-06-17 05:34:00     0
# 1   2  54.9 -111.7    ARU   1SPT  2021-06-18 05:34:00     0
# 2   4  54.9 -111.7    ARU   1SPT  2021-06-21 05:34:00     0
# 3   5  54.9 -111.4    ARU   1SPT  2021-06-30 05:39:00     0
# 4   6  54.9 -111.7    ARU   1SPT  2021-07-01 05:39:00     0
